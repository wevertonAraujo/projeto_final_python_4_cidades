# %%
# Gráficos representando o número de casos de covid-19 nas cidades do RN com maior contingente populacional. 
# Saúde e Bem-estar é o 3° objetivo da ONU para transformar nosso mundo.


#Bibliotecas utilizadas. 
import numpy as np
import matplotlib.pyplot as plt
 
#Largura da barra.
barWidth = 0.30
 
#Dados do covid-19 no RN há um mês atrás, retirados do site da sesap (BOLETIM EPIDEMIOLÓGICO Nº 65 (18/05/2020) | Versão unificada), acessado em 17/06/2020.

confirmados1 = [1380, 557, 245, 93, 41]
obitos1 = [41, 29, 7, 6, 3]
suspeitos1 = [ 4772, 623, 913, 380, 279]

# Definição da posição da barra no eixo X.
r1 = np.arange(len(confirmados1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
#Organização visual.
plt.bar(r1, confirmados1, color='#880000', width=barWidth, edgecolor='white', label='Confirmados')
plt.bar(r2, obitos1, color='#a3acff', width=barWidth, edgecolor='white', label='Óbitos')
plt.bar(r3, suspeitos1, color='#2d7f5e', width=barWidth, edgecolor='white', label='Suspeitos')
 
plt.title("Desenvolvimento do covid-19 no RN, Há um mês atrás", loc="left")
plt.xlabel("5 Cidades do RN com mais habitantes")
plt.ylabel("Nº relacionados ao covid-19")

plt.xticks([r + barWidth for r in range(len(confirmados1))], ['Natal', 'Mossoró', 'Parnamirim', 'SGA', 'Macaíba'])
 
#Exibição da legenda e do gráfico.
plt.legend()
plt.show()

# Gráfico 2 Desenvolvimento do covid-19 no RN, dia 17/06/2020.
import numpy as np
import matplotlib.pyplot as plt
 
# largura da barra
barWidth = 0.30
 
# Dados retirados do site da sesap acessado em 18/06/2020 (BOLETIM EPIDEMIOLÓGICO Nº 90 (17/06/2020)).

confirmados = [5957, 1783, 1562, 776, 283]
obitos = [229, 95, 41, 26, 14]
suspeitos = [12448, 1340, 2261, 792, 904]
 
# Definição da posição da barra no eixo X.
r1 = np.arange(len(confirmados))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
#Organização visual.
plt.bar(r1, confirmados, color='#880000', width=barWidth, edgecolor='white', label='Confirmados')
plt.bar(r2, obitos, color='#a3acff', width=barWidth, edgecolor='white', label='Óbitos')
plt.bar(r3, suspeitos, color='#2d7f5e', width=barWidth, edgecolor='white', label='Suspeitos')
 
plt.title("Desenvolvimento do covid-19 no RN, dia 17/06/2020 ", loc="left")
plt.xlabel("5 Cidades do RN com mais habitantes")
plt.ylabel("Nº relacionados ao covid-19")

plt.xticks([r + barWidth for r in range(len(confirmados))], ['Natal', 'Mossoró', 'Parnamirim', 'SGA', 'Macaíba'])
 
# Exibição da legenda e do gráfico.
plt.legend()
plt.show()


# Gráfico 3, Retrata apenas o Número de Óbitos e Recuperados.

import numpy as np
import matplotlib.pyplot as plt
 
# largura da barra.
barWidth = 0.30
 
# Dados retirados do site da sesap acessado em 18/06/2020 (BOLETIM EPIDEMIOLÓGICO Nº 90 (17/06/2020)).

obitos = [229, 95, 41, 26, 14]
recuperados= [925, 308, 167, 52, 85 ]
 
# Definir posição da barra no eixo X.
r1 = np.arange(len(confirmados))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
#Organização visual.

plt.bar(r2, obitos, color='#a3acff', width=barWidth, edgecolor='white', label='Óbitos')
plt.bar(r3, recuperados, color='#2716A7', width=barWidth, edgecolor='white', label='Recuperados')
 
 
plt.title("N° de óbitos e recuperados do covid-19 no RN ", loc="left")
plt.xlabel("5 Cidades do RN com mais habitantes")
plt.ylabel("Nº relacionados ao covid-19")

plt.xticks([r + barWidth for r in range(len(confirmados))], ['Natal', 'Mossoró', 'Parnamirim', 'SGA', 'Macaíba'])
 
# exibição do gráfico e da  legenda.
plt.legend()
plt.show()


print(" Autora: Nataly de Lima Marinho. ")
# Out:
#  Autora: Nataly de Lima Marinho.
