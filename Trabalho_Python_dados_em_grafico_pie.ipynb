# %%
import matplotlib.pyplot as plt
 
values = [7638, 2092, 2025,984 ]
colors = ['b', 'g', 'r', 'c']
labels = ['Natal', 'Parnamirim', 'Mossoró', 'São Gonçalo do Amarante']
explode = (0.1, 0, 0, 0)
plt.pie(values, colors=colors, labels= values,explode=explode,counterclock=False, shadow=True)
plt.title('Cidades com maior incidência de confirmados')
plt.legend(labels,loc=6)
plt.show()

print(" Autor: Pedro Thiago Pinheiro de Freitas ")
# Out:
#  Autor: Pedro Thiago Pinheiro de Freitas
